# %%
import re

rules = {  
    "EMI": [
        r"emi", r"installment", r"zero percent emi", r"0% interest", r"paisa finance", r"down payment"
    ],  
    "COD": [
        r"\bcod\b", r"cash on delivery", r"pay later"
    ],
    "ORTHO_FEATURES": [
        r"ortho", r"back problem", r"back pain", r"neck pain", r"slip disc", r"orthopaedic"
    ],  
    "ERGO_FEATURES": [
        r"ergo", r"ergonomic support", r"responsive foam" 
    ],  
    "COMPARISON": [
        r"difference", r"compare", r"comparison", r"which mattress", r"mattress comparison"
    ],  
    "WARRANTY": [
        r"warranty", r"cover"
    ],  
    "100_NIGHT_TRIAL_OFFER": [
        r"100 night", r"trial", r"exchange"
    ],
    "SIZE_CUSTOMIZATION": [
        r"custom size", r"customize", r"change size", r"size customization"
    ],
    "WHAT_SIZE_TO_ORDER": [
        r"what size", r"size chart", r"available sizes", r"feet", r"inches", r"king size"
    ],
    "LEAD_GEN": [
        r"call me", r"live agent", r"get in touch", r"schedule a callback", r"interested in buying", r"connect to an agent"
    ],
    "CHECK_PINCODE": [
        r"check pincode", r"deliver to my pincode", r"delivery possible"
    ],
    "DISTRIBUTORS": [
        r"showroom", r"distributors", r"retailers", r"offline stores"
    ],
    "MATTRESS_COST": [
        r"price", r"cost", r"how much", r"rate", r"mrp"
    ],
    "PRODUCT_VARIANTS": [
        r"product variants", r"mattress features", r"different products"
    ],
    "ABOUT_SOF_MATTRESS": [  
        r"about sof mattress", r"who are sof", r"sof mattress"
    ],  
    "DELAY_IN_DELIVERY": [
        r"delayed", r"why so long", r"not receive", r"so many days", r"late delivery"
    ],
    "ORDER_STATUS": [
        r"order status", r"track order", r"where is my order"
    ],
    "RETURN_EXCHANGE": [
        r"return", r"refund", r"exchange", r"replace"
    ],
    "CANCEL_ORDER": [
        r"cancel order", r"cancellation"
    ],
    "PILLOWS": [
        r"pillows", r"cushions"
    ],
    "OFFERS": [
        r"offers", r"discount", r"available offers", r"offer"
    ]  
}

# %%
def classify_sentence(sentence, rules=rules):
    sentence_lower = sentence.lower()  
    for intent, patterns in rules.items():  
        for pattern in patterns:  
            if re.search(pattern, sentence_lower):  
                return intent  
    return "UNKNOWN"  # If no patterns match, return UNKNOWN

# %%
import pandas as pd

df = pd.read_csv("../data/Tifin_Test_1/data/sofmattress_train.csv")
df
# Out:
#                                            sentence   label
# 0                      You guys provide EMI option?     EMI
# 1    Do you offer Zero Percent EMI payment options?     EMI
# 2                                           0% EMI.     EMI
# 3                                               EMI     EMI
# 4                             I want in installment     EMI
# ..                                              ...     ...
# 323              May I please know about the offers  OFFERS
# 324                                Available offers  OFFERS
# 325                              Is offer available  OFFERS
# 326                      Want to know the discount   OFFERS
# 327                 Tell me about the latest offers  OFFERS
#
# [328 rows x 2 columns]

# %%
df["intent"] = df["sentence"].apply(classify_sentence)

# %%
accuracy = (df['intent'] == df['label']).mean()
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.65

# %%
# wrong classifications
wrong_df = df[df['intent'] != df['label']].reset_index(drop=True)
wrong_classification_count = wrong_df.shape[0]
print("Number of wrong classifications:", wrong_classification_count)

# wrong where predicted intent is UNKNOWN
unknown_count = (wrong_df['intent'] == 'UNKNOWN').sum()
print(f"Number of unknown intents: {unknown_count}")

# wrong where predicted intent is not UNKNOWN
wrong_df = (wrong_df['intent'] != 'UNKNOWN').sum()
print(f"Number of wrong intents: {wrong_df}")
# Out:
# Number of wrong classifications: 116
# Number of unknown intents: 103
# Number of wrong intents: 13

# %%
from sklearn.metrics import classification_report
from matplotlib import pyplot as plt

report = classification_report(df['label'], df['intent'], zero_division=0)
print(report)
# Out:
#                        precision    recall  f1-score   support
#
# 100_NIGHT_TRIAL_OFFER       0.82      0.78      0.80        18
#    ABOUT_SOF_MATTRESS       0.89      0.73      0.80        11
#          CANCEL_ORDER       1.00      0.20      0.33        10
#         CHECK_PINCODE       1.00      0.30      0.46        10
#                   COD       1.00      1.00      1.00        12
#            COMPARISON       0.88      0.64      0.74        11
#     DELAY_IN_DELIVERY       1.00      0.55      0.71        11
#          DISTRIBUTORS       1.00      0.35      0.52        34
#                   EMI       1.00      1.00      1.00        25
#         ERGO_FEATURES       1.00      1.00      1.00        11
#              LEAD_GEN       1.00      0.57      0.73        21
#         MATTRESS_COST       1.00      0.95      0.98        22
#                OFFERS       0.83      1.00      0.91        10
#          ORDER_STATUS       1.00      0.33      0.50        21
#        ORTHO_FEATURES       0.82      0.82      0.82        17
#               PILLOWS       1.00      1.00      1.00        10
#      PRODUCT_VARIANTS       1.00      0.29      0.44        21
#       RETURN_EXCHANGE       1.00      0.71      0.83        14
#    SIZE_CUSTOMIZATION       0.50      0.22      0.31         9
#               UNKNOWN       0.00      0.00      0.00         0
#              WARRANTY       1.00      1.00      1.00        10
#    WHAT_SIZE_TO_ORDER       0.91      0.50      0.65        20
#
#              accuracy                           0.65       328
#             macro avg       0.89      0.63      0.71       328
#          weighted avg       0.95      0.65      0.73       328

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(df['label'], df['intent'])

actual_labels = sorted([*df['label'].unique(), "UNKNOWN"])
predicted_labels = sorted(df['intent'].unique())


plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=predicted_labels, yticklabels=actual_labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
wrong_df[wrong_df['intent'] != 'UNKNOWN']
# Out:
#                                               sentence                  label  \
# 65   What is the difference between the Ergo & Orth...             COMPARISON
# 66            Difference between Ergo & Ortho Mattress             COMPARISON
# 74                       Compare ergo & ortho variants             COMPARISON
# 87                         What is the 100-night offer  100_NIGHT_TRIAL_OFFER
# 96                              I want to check offers  100_NIGHT_TRIAL_OFFER
# 125                 Want to know the custom size chart     WHAT_SIZE_TO_ORDER
# 168  What is the price for size (x ft x y ft)? What...           DISTRIBUTORS
# 203                                   Custom size cost          MATTRESS_COST
# 225                 What are the SOF mattress products       PRODUCT_VARIANTS
# 228                             Which mattress is best       PRODUCT_VARIANTS
# 288                      Help me with exchange process        RETURN_EXCHANGE
# 291                                           Exchange        RETURN_EXCHANGE
# 292                                Looking to exchange        RETURN_EXCHANGE
#
#                     intent
# 65          ORTHO_FEATURES
# 66          ORTHO_FEATURES
# 74          ORTHO_FEATURES
# 87                  OFFERS
# 96                  OFFERS
# 125     SIZE_CUSTOMIZATION
# 168     WHAT_SIZE_TO_ORDER
# 203     SIZE_CUSTOMIZATION
# 225     ABOUT_SOF_MATTRESS
# 228             COMPARISON
# 288  100_NIGHT_TRIAL_OFFER
# 291  100_NIGHT_TRIAL_OFFER
# 292  100_NIGHT_TRIAL_OFFER

# %% [markdown]
# ## Findings after initial run
#
# 1. fix word boundaries. words like pin code was getting classified as "COD"
# 2. semantic sentance where exact keywords/regex patterns are not present are failing
# 3. majority of the cases which are failing are predicted as UNKNOWN. so if result is UNKNOWN, some other approach can be used.
# 4. using strict regexes instead of lousy ones will reduce the false positive rate.

# %%
wrong_df[:50]
# Out:
#                                               sentence                  label  \
# 49                                     back ache issue         ORTHO_FEATURES
# 51                    Do we have anything for backache         ORTHO_FEATURES
# 52           I am cervical and Lombard section problem         ORTHO_FEATURES
# 65   What is the difference between the Ergo & Orth...             COMPARISON
# 66            Difference between Ergo & Ortho Mattress             COMPARISON
# 72                    Is the mattress good for my back             COMPARISON
# 74                       Compare ergo & ortho variants             COMPARISON
# 87                         What is the 100-night offer  100_NIGHT_TRIAL_OFFER
# 95                          Can I try a mattress first  100_NIGHT_TRIAL_OFFER
# 96                              I want to check offers  100_NIGHT_TRIAL_OFFER
# 103                                    100 free Nights  100_NIGHT_TRIAL_OFFER
# 104         I want to change the size of the mattress.     SIZE_CUSTOMIZATION
# 105    Need some help in changing size of the mattress     SIZE_CUSTOMIZATION
# 108                                    Customise size      SIZE_CUSTOMIZATION
# 109                         Customisation is possible?     SIZE_CUSTOMIZATION
# 110         Will I get an option to Customise the size     SIZE_CUSTOMIZATION
# 111                   Can mattress size be customised?     SIZE_CUSTOMIZATION
# 112                               Mattress size change     SIZE_CUSTOMIZATION
# 113                        Can you help with the size?     WHAT_SIZE_TO_ORDER
# 115                  How do I know the size of my bed?     WHAT_SIZE_TO_ORDER
# 117                                             Length     WHAT_SIZE_TO_ORDER
# 119                                                6*3     WHAT_SIZE_TO_ORDER
# 123                           Share the size structure     WHAT_SIZE_TO_ORDER
# 124                      What are the sizes available?     WHAT_SIZE_TO_ORDER
# 125                 Want to know the custom size chart     WHAT_SIZE_TO_ORDER
# 126                                      Mattress size     WHAT_SIZE_TO_ORDER
# 129                                 What are the sizes     WHAT_SIZE_TO_ORDER
# 130              What are the available mattress sizes     WHAT_SIZE_TO_ORDER
# 139                               Arrange a call back                LEAD_GEN
# 142                                 I want to buy this               LEAD_GEN
# 143                                        How to buy?               LEAD_GEN
# 144                                       How to order               LEAD_GEN
# 145                                    I want to order               LEAD_GEN
# 148                                 I want a call back               LEAD_GEN
# 149                                 I need a call back               LEAD_GEN
# 152                                      I want to buy               LEAD_GEN
# 153               Need a call from your representative               LEAD_GEN
# 157                   Will you be able to deliver here          CHECK_PINCODE
# 158            Can you make delivery on this pin code?          CHECK_PINCODE
# 159                      Can you deliver on my pincode          CHECK_PINCODE
# 160                                  Do you deliver to          CHECK_PINCODE
# 161               Can you please deliver on my pincode          CHECK_PINCODE
# 162                    Need a delivery on this pincode          CHECK_PINCODE
# 163                 Can I get delivery on this pincode          CHECK_PINCODE
# 167           Where can I see the product before I buy           DISTRIBUTORS
# 168  What is the price for size (x ft x y ft)? What...           DISTRIBUTORS
# 175                                   Nearby Show room           DISTRIBUTORS
# 177                                         Need store           DISTRIBUTORS
# 178                                  Need Nearby Store           DISTRIBUTORS
# 179                                       Nearest shop           DISTRIBUTORS
#
#                  intent
# 49              UNKNOWN
# 51              UNKNOWN
# 52              UNKNOWN
# 65       ORTHO_FEATURES
# 66       ORTHO_FEATURES
# 72              UNKNOWN
# 74       ORTHO_FEATURES
# 87               OFFERS
# 95              UNKNOWN
# 96               OFFERS
# 103             UNKNOWN
# 104             UNKNOWN
# 105             UNKNOWN
# 108             UNKNOWN
# 109             UNKNOWN
# 110             UNKNOWN
# 111             UNKNOWN
# 112             UNKNOWN
# 113             UNKNOWN
# 115             UNKNOWN
# 117             UNKNOWN
# 119             UNKNOWN
# 123             UNKNOWN
# 124             UNKNOWN
# 125  SIZE_CUSTOMIZATION
# 126             UNKNOWN
# 129             UNKNOWN
# 130             UNKNOWN
# 139             UNKNOWN
# 142             UNKNOWN
# 143             UNKNOWN
# 144             UNKNOWN
# 145             UNKNOWN
# 148             UNKNOWN
# 149             UNKNOWN
# 152             UNKNOWN
# 153             UNKNOWN
# 157             UNKNOWN
# 158             UNKNOWN
# 159             UNKNOWN
# 160             UNKNOWN
# 161             UNKNOWN
# 162             UNKNOWN
# 163             UNKNOWN
# 167             UNKNOWN
# 168  WHAT_SIZE_TO_ORDER
# 175             UNKNOWN
# 177             UNKNOWN
# 178             UNKNOWN
# 179             UNKNOWN
